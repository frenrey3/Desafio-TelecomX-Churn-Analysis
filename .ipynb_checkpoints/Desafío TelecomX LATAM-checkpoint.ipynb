# %% [markdown]
# #📌 Extracción

# %%
# Extracción de datos desde URL remota con manejo de errores HTTP y de decodificación JSON

import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


resultado = None # Inicializar

try:
    TelecomX_Data = requests.get('https://storage.googleapis.com/enrique-data-bucket/TelecomX_Data.json')
    TelecomX_Data.raise_for_status() # Verificar errores HTTP
    resultado = json.loads(TelecomX_Data.text) # Esto debe ser una lista de diccionarios
    print(f"✅ JSON crudo cargado y parseado. Número de registros: {len(resultado) if isinstance(resultado, list) else 'No es una lista'}")
except requests.exceptions.RequestException as e_req:
    print(f"❌ Error al descargar los datos: {e_req}")
except json.JSONDecodeError as e_json:
    print(f"❌ Error al parsear el JSON. El contenido no es un JSON válido: {e_json}")
except Exception as e_other:
    print(f"❌ Ocurrió un error inesperado: {e_other}")
# Out:
# ✅ JSON crudo cargado y parseado. Número de registros: 7267

# %%
# Normalización y Creación del DataFrame (añadiendo una verificación)

if resultado is not None and isinstance(resultado, list) and len(resultado) > 0:
    df = pd.json_normalize(resultado)
    print(f"✅ DataFrame normalizado. Dimensiones: {df.shape}")
    df_original_normalized = df.copy()
else:
    print("❌ No se pudo crear el DataFrame porque 'resultado' no es una lista válida de datos o está vacía.")
    df = pd.DataFrame()

df
# Out:
# ✅ DataFrame normalizado. Dimensiones: (7267, 21)
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# 1                  No                  No                9                Yes
# 2                  No                  No                4                Yes
# 3                 Yes                  No               13                Yes
# 4                 Yes                  No                3                Yes
# ...               ...                 ...              ...                ...
# 7262               No                  No               13                Yes
# 7263              Yes                  No               22                Yes
# 7264               No                  No                2                Yes
# 7265              Yes                 Yes               67                Yes
# 7266              Yes                 Yes               63                 No
#
#      phone.MultipleLines internet.InternetService  ... internet.OnlineBackup  \
# 0                     No                      DSL  ...                   Yes
# 1                    Yes                      DSL  ...                    No
# 2                     No              Fiber optic  ...                    No
# 3                     No              Fiber optic  ...                   Yes
# 4                     No              Fiber optic  ...                    No
# ...                  ...                      ...  ...                   ...
# 7262                  No                      DSL  ...                    No
# 7263                 Yes              Fiber optic  ...                    No
# 7264                  No                      DSL  ...                   Yes
# 7265                  No                      DSL  ...                    No
# 7266    No phone service                      DSL  ...                   Yes
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 0                           No                  Yes                  Yes
# 1                           No                   No                   No
# 2                          Yes                   No                   No
# 3                          Yes                   No                  Yes
# 4                           No                  Yes                  Yes
# ...                        ...                  ...                  ...
# 7262                        No                  Yes                   No
# 7263                        No                   No                   No
# 7264                        No                   No                   No
# 7265                       Yes                  Yes                   No
# 7266                       Yes                   No                  Yes
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 0                          No         One year                      Yes
# 1                         Yes   Month-to-month                       No
# 2                          No   Month-to-month                      Yes
# 3                         Yes   Month-to-month                      Yes
# 4                          No   Month-to-month                      Yes
# ...                       ...              ...                      ...
# 7262                       No         One year                       No
# 7263                      Yes   Month-to-month                      Yes
# 7264                       No   Month-to-month                      Yes
# 7265                      Yes         Two year                       No
# 7266                      Yes         Two year                       No
#
#      account.PaymentMethod account.Charges.Monthly  account.Charges.Total
# 0             Mailed check                   65.60                  593.3
# 1             Mailed check                   59.90                  542.4
# 2         Electronic check                   73.90                 280.85
# 3         Electronic check                   98.00                1237.85
# 4             Mailed check                   83.90                  267.4
# ...                    ...                     ...                    ...
# 7262          Mailed check                   55.15                  742.9
# 7263      Electronic check                   85.10                 1873.7
# 7264          Mailed check                   50.30                  92.75
# 7265          Mailed check                   67.85                4627.65
# 7266      Electronic check                   59.00                 3707.6
#
# [7267 rows x 21 columns]

# %% [markdown]
# #🔧 Transformación

# %%
# Información general del DataFrame
df.info()

# Estadísticas descriptivas para variables numéricas
df.describe()

# Dimensiones del DataFrame
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
#  13  internet.TechSupport       7267 non-null   object
#  14  internet.StreamingTV       7267 non-null   object
#  15  internet.StreamingMovies   7267 non-null   object
#  16  account.Contract           7267 non-null   object
#  17  account.PaperlessBilling   7267 non-null   object
#  18  account.PaymentMethod      7267 non-null   object
#  19  account.Charges.Monthly    7267 non-null   float64
#  20  account.Charges.Total      7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB
# (7267, 21)

# %%
# Conteo absoluto de valores nulos (>0)
df.isnull().sum()[lambda x: x > 0]

# Porcentaje de valores nulos (>0)
(df.isnull().sum() / len(df) * 100)[lambda x: x > 0]

# Conteo de filas duplicadas
df.duplicated().sum()

# Eliminación de filas duplicadas
df = df.drop_duplicates()

# %%
# Reemplazar strings vacíos con None y convertir columna a numérico
df["account.Charges.Total"] = pd.to_numeric(
    df["account.Charges.Total"].replace("", None), errors="coerce"
)

# %%
# Conteo de valores nulos por columna
df.isna().sum()

# Conteo de strings vacíos por columna
(df == '').sum()

# Verificación de duplicados nuevamente
df.duplicated().sum()

# Eliminación de duplicados (si quedara alguno)
df = df.drop_duplicates()

# Tipos de datos por columna
df.dtypes

# Valores únicos en la columna 'Churn'
df["Churn"].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
# Eliminar filas sin etiqueta de churn
df = df[df["Churn"] != ''].copy()

# Rellenar cargos totales faltantes con 0
df["account.Charges.Total"] = df["account.Charges.Total"].fillna(0)

# %%
# Eliminar espacios y convertir a minúsculas en todas las columnas de tipo objeto
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip().str.lower()

# %%
columns_to_clean = [
    "internet.OnlineSecurity", "internet.OnlineBackup", "internet.DeviceProtection",
    "internet.TechSupport", "internet.StreamingTV", "internet.StreamingMovies", 
    "phone.MultipleLines"
]

# Solo limpiar columnas que existen
existing_columns = [col for col in columns_to_clean if col in df.columns]

df[existing_columns] = df[existing_columns].replace({
    "no internet service": "no",
    "no phone service": "no"
})

# %%
# Columnas en las que puede aparecer "no internet service" o "no phone service"
columns_to_clean = [
    "onlinesecurity", "onlinebackup", "deviceprotection",
    "techsupport", "streamingtv", "streamingmovies", "multiplelines"
]

# Verificar que las columnas existen antes de limpiar
existing_columns = [col for col in columns_to_clean if col in df.columns]

# Reemplazar valores como "no internet service" y "no phone service" por "no"
df[existing_columns] = df[existing_columns].replace({
    "no internet service": "no",
    "no phone service": "no"
})

# %%
# Quitar prefijos de columnas
df.columns = df.columns.str.replace(r'^(customer\.|phone\.|internet\.|account\.)', '', regex=True)

# Convertir nombres de columnas a minúsculas
df.columns = df.columns.str.lower()

# Mostrar resultado
print("Columnas finales:\n", df.columns.tolist())
# Out:
# Columnas finales:
#  ['customerid', 'churn', 'gender', 'seniorcitizen', 'partner', 'dependents', 'tenure', 'phoneservice', 'multiplelines', 'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling', 'paymentmethod', 'charges.monthly', 'charges.total']

# %%
columns_with_case_issues = [
    "churn", "gender", "partner", "dependents", "phoneservice",
    "multiplelines", "internetservice", "onlinesecurity", "onlinebackup",
    "deviceprotection", "techsupport", "streamingtv", "streamingmovies",
    "contract", "paperlessbilling", "paymentmethod"
]

# Verificar si todas las columnas existen
missing_cols = [col for col in columns_with_case_issues if col not in df.columns]
if missing_cols:
    print("Columnas faltantes:", missing_cols)
else:
    # Convertir valores a minúsculas
    df[columns_with_case_issues] = df[columns_with_case_issues].apply(lambda col: col.str.lower())

    # Mostrar valores únicos para verificación
    for col in columns_with_case_issues:
        print(f"\nValores únicos en {col}:\n", df[col].unique())
# Out:
# Valores únicos en churn:
#  ['no' 'yes']
#
# Valores únicos en gender:
#  ['female' 'male']
#
# Valores únicos en partner:
#  ['yes' 'no']
#
# Valores únicos en dependents:
#  ['yes' 'no']
#
# Valores únicos en phoneservice:
#  ['yes' 'no']
#
# Valores únicos en multiplelines:
#  ['no' 'yes']
#
# Valores únicos en internetservice:
#  ['dsl' 'fiber optic' 'no']
#
# Valores únicos en onlinesecurity:
#  ['no' 'yes']
#
# Valores únicos en onlinebackup:
#  ['yes' 'no']
#
# Valores únicos en deviceprotection:
#  ['no' 'yes']
#
# Valores únicos en techsupport:
#  ['yes' 'no']
#
# Valores únicos en streamingtv:
#  ['yes' 'no']
#
# Valores únicos en streamingmovies:
#  ['no' 'yes']
#
# Valores únicos en contract:
#  ['one year' 'month-to-month' 'two year']
#
# Valores únicos en paperlessbilling:
#  ['yes' 'no']
#
# Valores únicos en paymentmethod:
#  ['mailed check' 'electronic check' 'credit card (automatic)'
#  'bank transfer (automatic)']

# %%
# Reemplazar espacios y paréntesis en valores categóricos clave (etiquetas legibles para ML)

columns_to_sanitize = [
    "paymentmethod", "contract", "internetservice"
]

# Aplicar limpieza: reemplazar espacios por guiones bajos y eliminar paréntesis
for col in columns_to_sanitize:
    if col in df.columns:
        df[col] = df[col].str.replace(' ', '_')\
                         .str.replace('(', '', regex=False)\
                         .str.replace(')', '', regex=False)

# Verificación final de valores únicos por columna clave
columns_final_check = [
    "churn", "gender", "partner", "dependents", "phoneservice",
    "multiplelines", "internetservice", "onlinesecurity", "onlinebackup",
    "deviceprotection", "techsupport", "streamingtv", "streamingmovies",
    "contract", "paperlessbilling", "paymentmethod"
]

for col in columns_final_check:
    if col in df.columns:
        print(f"\nValores únicos en {col}:\n", df[col].unique())
# Out:
# Valores únicos en churn:
#  ['no' 'yes']
#
# Valores únicos en gender:
#  ['female' 'male']
#
# Valores únicos en partner:
#  ['yes' 'no']
#
# Valores únicos en dependents:
#  ['yes' 'no']
#
# Valores únicos en phoneservice:
#  ['yes' 'no']
#
# Valores únicos en multiplelines:
#  ['no' 'yes']
#
# Valores únicos en internetservice:
#  ['dsl' 'fiber_optic' 'no']
#
# Valores únicos en onlinesecurity:
#  ['no' 'yes']
#
# Valores únicos en onlinebackup:
#  ['yes' 'no']
#
# Valores únicos en deviceprotection:
#  ['no' 'yes']
#
# Valores únicos en techsupport:
#  ['yes' 'no']
#
# Valores únicos en streamingtv:
#  ['yes' 'no']
#
# Valores únicos en streamingmovies:
#  ['no' 'yes']
#
# Valores únicos en contract:
#  ['one_year' 'month-to-month' 'two_year']
#
# Valores únicos en paperlessbilling:
#  ['yes' 'no']
#
# Valores únicos en paymentmethod:
#  ['mailed_check' 'electronic_check' 'credit_card_automatic'
#  'bank_transfer_automatic']

# %%
# Definir columnas binarias explícitamente
binary_cols = [
    'churn', 'partner', 'dependents', 'phoneservice',
    'multiplelines', 'onlinesecurity', 'onlinebackup',
    'deviceprotection', 'techsupport', 'streamingtv',
    'streamingmovies', 'paperlessbilling'
]

# Conversión binaria explícita
df[binary_cols] = df[binary_cols].replace({'yes': 1, 'no': 0})
df[binary_cols] = df[binary_cols].astype(int)

# Conversión de género
df[binary_cols] = df[binary_cols].replace({'yes': 1, 'no': 0}).astype(int)
df['gender'] = df['gender'].replace({'female': 0, 'male': 1}).astype(int)

# Convertir columnas categóricas
category_cols = [
    'multiplelines', 'internetservice',
    'contract', 'paymentmethod'
]
df[category_cols] = df[category_cols].astype('category')

# Asegurar que customerid sea string
df['customerid'] = df['customerid'].astype('string')

# %%
df
# Out:
#       customerid  churn  gender  seniorcitizen  partner  dependents  tenure  \
# 0     0002-orfbo      0       0              0        1           1       9
# 1     0003-mknfe      0       1              0        0           0       9
# 2     0004-tlhlj      1       1              0        0           0       4
# 3     0011-igkff      1       1              1        1           0      13
# 4     0013-exchz      1       0              1        1           0       3
# ...          ...    ...     ...            ...      ...         ...     ...
# 7262  9987-lutyd      0       0              0        0           0      13
# 7263  9992-rramn      1       1              0        1           0      22
# 7264  9992-ujoel      0       1              0        0           0       2
# 7265  9993-lhieb      0       1              0        1           1      67
# 7266  9995-hotoh      0       1              0        1           1      63
#
#       phoneservice multiplelines internetservice  ...  deviceprotection  \
# 0                1             0             dsl  ...                 0
# 1                1             1             dsl  ...                 0
# 2                1             0     fiber_optic  ...                 1
# 3                1             0     fiber_optic  ...                 1
# 4                1             0     fiber_optic  ...                 0
# ...            ...           ...             ...  ...               ...
# 7262             1             0             dsl  ...                 0
# 7263             1             1     fiber_optic  ...                 0
# 7264             1             0             dsl  ...                 0
# 7265             1             0             dsl  ...                 1
# 7266             0             0             dsl  ...                 1
#
#       techsupport  streamingtv  streamingmovies        contract  \
# 0               1            1                0        one_year
# 1               0            0                1  month-to-month
# 2               0            0                0  month-to-month
# 3               0            1                1  month-to-month
# 4               1            1                0  month-to-month
# ...           ...          ...              ...             ...
# 7262            1            0                0        one_year
# 7263            0            0                1  month-to-month
# 7264            0            0                0  month-to-month
# 7265            1            0                1        two_year
# 7266            0            1                1        two_year
#
#       paperlessbilling     paymentmethod  charges.monthly charges.total  \
# 0                    1      mailed_check            65.60        593.30
# 1                    0      mailed_check            59.90        542.40
# 2                    1  electronic_check            73.90        280.85
# 3                    1  electronic_check            98.00       1237.85
# 4                    1      mailed_check            83.90        267.40
# ...                ...               ...              ...           ...
# 7262                 0      mailed_check            55.15        742.90
# 7263                 1  electronic_check            85.10       1873.70
# 7264                 1      mailed_check            50.30         92.75
# 7265                 0      mailed_check            67.85       4627.65
# 7266                 0  electronic_check            59.00       3707.60
#
#       daily_charges
# 0              2.19
# 1              2.00
# 2              2.46
# 3              3.27
# 4              2.80
# ...             ...
# 7262           1.84
# 7263           2.84
# 7264           1.68
# 7265           2.26
# 7266           1.97
#
# [7043 rows x 22 columns]

# %% [markdown]
# #📊 Carga y análisis

# %%
# CREACIÓN DE LA COLUMNA 'daily_charges'

if not df.empty and 'charges.monthly' in df.columns:
    print("\n--- Creando la columna 'daily_charges' ---")
    
    # Para el cálculo de "días en un mes", se puede usar un promedio.
    # Un enfoque común es usar 30.4375 días por mes (365.25 días/año / 12 meses/año).
    dias_en_mes_promedio = 30

    # Asegurarse de que 'charges.monthly' sea numérico antes de la división
    if pd.api.types.is_numeric_dtype(df['charges.monthly']):
        df['daily_charges'] = df['charges.monthly'] / dias_en_mes_promedio

        # Redondear a 2 decimales
        df['daily_charges'] = df['daily_charges'].round(2)
        
        print("Columna 'daily_charges' creada exitosamente.")
        display(df[['charges.monthly', 'daily_charges']].head())
        
        print(f"\nTipo de dato de 'daily_charges': {df['daily_charges'].dtype}")
        print("\nEstadísticas descriptivas de 'daily_charges':")
        display(df['daily_charges'].describe())
    else:
        print(f"❌ Error: La columna 'charges.monthly' no es de tipo numérico. No se puede calcular 'daily_charges'. "
              f"Tipo actual: {df['charges.monthly'].dtype}")
        
    # Opcional: Verificar info del DataFrame completo después de añadir la nueva columna
    # print("\n--- Información del DataFrame con 'daily_charges' ---")
    # df.info()
else:
    print("DataFrame vacío o la columna 'charges.monthly' no existe.")
# Out:
# --- Creando la columna 'daily_charges' ---
# Columna 'daily_charges' creada exitosamente.
#    charges.monthly  daily_charges
# 0             65.6           2.19
# 1             59.9           2.00
# 2             73.9           2.46
# 3             98.0           3.27
# 4             83.9           2.80
# Tipo de dato de 'daily_charges': float64
#
# Estadísticas descriptivas de 'daily_charges':
# count    7043.000000
# mean        2.158675
# std         1.003088
# min         0.610000
# 25%         1.180000
# 50%         2.340000
# 75%         2.990000
# max         3.960000
# Name: daily_charges, dtype: float64

# %%
df
# Out:
#       customerid  churn  gender  seniorcitizen  partner  dependents  tenure  \
# 0     0002-orfbo      0       0              0        1           1       9
# 1     0003-mknfe      0       1              0        0           0       9
# 2     0004-tlhlj      1       1              0        0           0       4
# 3     0011-igkff      1       1              1        1           0      13
# 4     0013-exchz      1       0              1        1           0       3
# ...          ...    ...     ...            ...      ...         ...     ...
# 7262  9987-lutyd      0       0              0        0           0      13
# 7263  9992-rramn      1       1              0        1           0      22
# 7264  9992-ujoel      0       1              0        0           0       2
# 7265  9993-lhieb      0       1              0        1           1      67
# 7266  9995-hotoh      0       1              0        1           1      63
#
#       phoneservice multiplelines internetservice  ...  deviceprotection  \
# 0                1             0             dsl  ...                 0
# 1                1             1             dsl  ...                 0
# 2                1             0     fiber_optic  ...                 1
# 3                1             0     fiber_optic  ...                 1
# 4                1             0     fiber_optic  ...                 0
# ...            ...           ...             ...  ...               ...
# 7262             1             0             dsl  ...                 0
# 7263             1             1     fiber_optic  ...                 0
# 7264             1             0             dsl  ...                 0
# 7265             1             0             dsl  ...                 1
# 7266             0             0             dsl  ...                 1
#
#       techsupport  streamingtv  streamingmovies        contract  \
# 0               1            1                0        one_year
# 1               0            0                1  month-to-month
# 2               0            0                0  month-to-month
# 3               0            1                1  month-to-month
# 4               1            1                0  month-to-month
# ...           ...          ...              ...             ...
# 7262            1            0                0        one_year
# 7263            0            0                1  month-to-month
# 7264            0            0                0  month-to-month
# 7265            1            0                1        two_year
# 7266            0            1                1        two_year
#
#       paperlessbilling     paymentmethod  charges.monthly charges.total  \
# 0                    1      mailed_check            65.60        593.30
# 1                    0      mailed_check            59.90        542.40
# 2                    1  electronic_check            73.90        280.85
# 3                    1  electronic_check            98.00       1237.85
# 4                    1      mailed_check            83.90        267.40
# ...                ...               ...              ...           ...
# 7262                 0      mailed_check            55.15        742.90
# 7263                 1  electronic_check            85.10       1873.70
# 7264                 1      mailed_check            50.30         92.75
# 7265                 0      mailed_check            67.85       4627.65
# 7266                 0  electronic_check            59.00       3707.60
#
#       daily_charges
# 0              2.19
# 1              2.00
# 2              2.46
# 3              3.27
# 4              2.80
# ...             ...
# 7262           1.84
# 7263           2.84
# 7264           1.68
# 7265           2.26
# 7266           1.97
#
# [7043 rows x 22 columns]

# %% [markdown]
# ## 2. Análisis de Datos (Carga y Análisis según tu estructura)
#
# ### 2.1. Análisis Descriptivo de los Datos
#
# Para comenzar, realizaremos un análisis descriptivo de los datos, calculando métricas como media, mediana, desviación estándar y otras medidas que ayuden a comprender mejor la distribución y el comportamiento de los clientes. Se utilizará `DataFrame.describe()` y otras funciones de Pandas.

# %%
# CELDA: ANÁLISIS DESCRIPTIVO GENERAL (CÁLCULO DE MÉTRICAS)

if not df.empty:
    print("--- ESTADÍSTICAS DESCRIPTIVAS DEL DATAFRAME COMPLETO ---")

    print("\n--- Información General (revisión post-limpieza) ---")
    df.info()

    print("\n--- Estadísticas Descriptivas - Variables Numéricas y las convertidas a 0/1 ---")
    try:
        descriptivas_numericas = df.describe(include=[np.number, 'Int64']) 
        display(descriptivas_numericas.transpose())
    except Exception as e:
        print(f"Error al generar describe para numéricas/booleanas: {e}")
        try:
            print("Intentando describe() seleccionando dtypes explícitamente...")
            display(df.select_dtypes(include=['float64', 'int64', 'Int64']).describe().transpose())
        except Exception as e_fallback:
            print(f"Describe() con dtypes explícitos también falló: {e_fallback}")

    print("\n--- Estadísticas Descriptivas - Variables Categóricas (object y category) ---")
    try:
        cols_categoricas_reales = df.select_dtypes(include=['object', 'category', 'string']).columns
        if not cols_categoricas_reales.empty:
            cols_para_describir_cat = [col for col in cols_categoricas_reales if col.lower() != 'customerid']
            if cols_para_describir_cat:
                descriptivas_categoricas = df[cols_para_describir_cat].describe().transpose()
                display(descriptivas_categoricas)
            else:
                print("No hay columnas categóricas (excluyendo customerid) para describir.")
        else:
            print("No hay columnas de tipo 'object', 'category' o 'string' para describir.")
    except Exception as e:
        print(f"Error al generar describe para categóricas: {e}")
        
    print("\n--- Métricas Específicas (Ejemplos) ---")
    cols_para_metricas = ['tenure', 'charges.monthly', 'charges.total', 'daily_charges']
    cols_para_metricas_existentes = [col for col in cols_para_metricas if col in df.columns and pd.api.types.is_numeric_dtype(df[col])]
    
    if cols_para_metricas_existentes:
        print("\nMedias:")
        display(df[cols_para_metricas_existentes].mean().to_frame(name='Media'))
        print("\nMedianas:")
        display(df[cols_para_metricas_existentes].median().to_frame(name='Mediana'))
        print("\nDesviación Estándar:")
        display(df[cols_para_metricas_existentes].std().to_frame(name='Desv. Estándar'))
    else:
        print("No hay columnas numéricas suficientes para calcular métricas específicas.")

    print("\n--- Conteo de Valores Únicos por Columna (Cardinalidad) ---")
    try:
        display(df.nunique(dropna=False).sort_values(ascending=False).to_frame(name='Valores Únicos'))
    except Exception as e:
        print(f"Error al calcular nunique: {e}")
else:
    print("El DataFrame está vacío. No se puede realizar el análisis descriptivo.")
# Out:
# --- ESTADÍSTICAS DESCRIPTIVAS DEL DATAFRAME COMPLETO ---
#
# --- Información General (revisión post-limpieza) ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   string
#  1   churn             7043 non-null   int64
#  2   gender            7043 non-null   int64
#  3   seniorcitizen     7043 non-null   int64
#  4   partner           7043 non-null   int64
#  5   dependents        7043 non-null   int64
#  6   tenure            7043 non-null   int64
#  7   phoneservice      7043 non-null   int64
#  8   multiplelines     7043 non-null   category
#  9   internetservice   7043 non-null   category
#  10  onlinesecurity    7043 non-null   int64
#  11  onlinebackup      7043 non-null   int64
#  12  deviceprotection  7043 non-null   int64
#  13  techsupport       7043 non-null   int64
#  14  streamingtv       7043 non-null   int64
#  15  streamingmovies   7043 non-null   int64
#  16  contract          7043 non-null   category
#  17  paperlessbilling  7043 non-null   int64
#  18  paymentmethod     7043 non-null   category
#  19  charges.monthly   7043 non-null   float64
#  20  charges.total     7043 non-null   float64
#  21  daily_charges     7043 non-null   float64
# dtypes: category(4), float64(3), int64(14), string(1)
# memory usage: 1.0 MB
#
# --- Estadísticas Descriptivas - Variables Numéricas y las convertidas a 0/1 ---
#                    count         mean          std    min     25%      50%  \
# churn             7043.0     0.265370     0.441561   0.00    0.00     0.00
# gender            7043.0     0.504756     0.500013   0.00    0.00     1.00
# seniorcitizen     7043.0     0.162147     0.368612   0.00    0.00     0.00
# partner           7043.0     0.483033     0.499748   0.00    0.00     0.00
# dependents        7043.0     0.299588     0.458110   0.00    0.00     0.00
# tenure            7043.0    32.371149    24.559481   0.00    9.00    29.00
# phoneservice      7043.0     0.903166     0.295752   0.00    1.00     1.00
# onlinesecurity    7043.0     0.286668     0.452237   0.00    0.00     0.00
# onlinebackup      7043.0     0.344881     0.475363   0.00    0.00     0.00
# deviceprotection  7043.0     0.343888     0.475038   0.00    0.00     0.00
# techsupport       7043.0     0.290217     0.453895   0.00    0.00     0.00
# streamingtv       7043.0     0.384353     0.486477   0.00    0.00     0.00
# streamingmovies   7043.0     0.387903     0.487307   0.00    0.00     0.00
# paperlessbilling  7043.0     0.592219     0.491457   0.00    0.00     1.00
# charges.monthly   7043.0    64.761692    30.090047  18.25   35.50    70.35
# charges.total     7043.0  2279.734304  2266.794470   0.00  398.55  1394.55
# daily_charges     7043.0     2.158675     1.003088   0.61    1.18     2.34
#
#                       75%      max
# churn                1.00     1.00
# gender               1.00     1.00
# seniorcitizen        0.00     1.00
# partner              1.00     1.00
# dependents           1.00     1.00
# tenure              55.00    72.00
# phoneservice         1.00     1.00
# onlinesecurity       1.00     1.00
# onlinebackup         1.00     1.00
# deviceprotection     1.00     1.00
# techsupport          1.00     1.00
# streamingtv          1.00     1.00
# streamingmovies      1.00     1.00
# paperlessbilling     1.00     1.00
# charges.monthly     89.85   118.75
# charges.total     3786.60  8684.80
# daily_charges        2.99     3.96
# --- Estadísticas Descriptivas - Variables Categóricas (object y category) ---
#                 count unique               top  freq
# multiplelines    7043      2                 0  4072
# internetservice  7043      3       fiber_optic  3096
# contract         7043      3    month-to-month  3875
# paymentmethod    7043      4  electronic_check  2365
# --- Métricas Específicas (Ejemplos) ---
#
# Medias:
#                        Media
# tenure             32.371149
# charges.monthly    64.761692
# charges.total    2279.734304
# daily_charges       2.158675
# Medianas:
#                  Mediana
# tenure             29.00
# charges.monthly    70.35
# charges.total    1394.55
# daily_charges       2.34
# Desviación Estándar:
#                  Desv. Estándar
# tenure                24.559481
# charges.monthly       30.090047
# charges.total       2266.794470
# daily_charges          1.003088
# --- Conteo de Valores Únicos por Columna (Cardinalidad) ---
#                   Valores Únicos
# customerid                  7043
# charges.total               6531
# charges.monthly             1585
# daily_charges                321
# tenure                        73
# paymentmethod                  4
# contract                       3
# internetservice                3
# dependents                     2
# gender                         2
# churn                          2
# partner                        2
# seniorcitizen                  2
# phoneservice                   2
# techsupport                    2
# deviceprotection               2
# onlinebackup                   2
# onlinesecurity                 2
# multiplelines                  2
# paperlessbilling               2
# streamingtv                    2
# streamingmovies                2

# %% [markdown]
# ### 2.2. Visualización Descriptiva Univariada
#
# #### 2.2.1. Distribución de la Variable Objetivo (Churn)
# En este paso, el objetivo es comprender cómo está distribuida la variable "churn" (evasión) entre los clientes. Utilizaremos un gráfico de barras para visualizar la proporción de clientes que permanecieron (0) y los que se dieron de baja (1).

# %%
# CELDA: VISUALIZACIÓN MEJORADA DE LA DISTRIBUCIÓN DE CHURN (CON GRID FINA)
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker # Necesario para los locators

col_churn = 'churn' 

if not df.empty and col_churn in df.columns:
    plt.figure(figsize=(8, 6))
    
    churn_labels_for_plot = df[col_churn].map({0: 'Permanecen (0)', 1: 'Evaden (1)'})
    
    ax = sns.countplot(
        x=churn_labels_for_plot,
        hue=churn_labels_for_plot, 
        palette=['#3498db', '#e74c3c'],
        order=['Permanecen (0)', 'Evaden (1)'],
        legend=False
    )
    
    plt.title('Distribución de Evasión de Clientes (Churn)', 
              fontsize=18, fontweight='bold', pad=25) # Aumenté un poco el pad y fontsize
    plt.xlabel('Estado del Cliente', fontsize=14, fontweight='bold', labelpad=15) # labelpad para espacio
    plt.ylabel('Número de Clientes', fontsize=14, fontweight='bold', labelpad=15) # labelpad para espacio
    
    total = len(df[col_churn])
    max_height = 0 # Para calcular el límite superior del eje Y
    
    for p in ax.patches:
        count = int(p.get_height())
        if count > max_height: # Actualizar max_height
            max_height = count
        percentage = f'{100 * count / total:.1f}%'
        
        ax.annotate(f'{count}\n({percentage})', 
                    (p.get_x() + p.get_width() / 2., count), 
                    ha='center',
                    va='bottom', 
                    fontsize=10, # Ligeramente más pequeño para no saturar
                    fontweight='bold',
                    color='#333333', # Un gris oscuro para el texto
                    xytext=(0, 5),  # 5 puntos arriba de la barra
                    textcoords='offset points')
    
    ax.set_ylim(0, max_height * 1.15) # 15% más espacio arriba para el texto

    # --- ESTILO DE SPINES Y TICKS ---
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    # ax.spines['left'].set_visible(False) # Considerar mantenerlo para referencia del eje Y si no poner grid fina
    
    ax.tick_params(axis='x', 
                   length=0, 
                   labelsize=12, # Ligeramente más grande
                   labelcolor='#2c3e50',
                   pad=10) 
    
    ax.tick_params(axis='y', 
                   labelsize=11, # Ligeramente más grande
                   labelcolor='#2c3e50',
                   left=True) # Mantener los ticks si quieres grid fina

    ax.spines['bottom'].set_linewidth(1.5)
    ax.spines['bottom'].set_color('#34495e')
    ax.spines['left'].set_linewidth(1.0) # Si decides mantenerlo
    ax.spines['left'].set_color('#34495e') # Si decides mantenerlo

    # --- CONFIGURACIÓN DE LA GRID FINA ---
    # Grid principal (líneas más gruesas o visibles)
    ax.yaxis.grid(True, linestyle='-', linewidth=0.7, alpha=0.6, color='#cccccc') # Grid principal más visible
    
    # Grid secundaria/fina (líneas más sutiles entre las principales)
    # Para esto, a menudo necesitas definir los locators.
    # Por ejemplo, si quieres una línea cada 500 clientes y una más fina cada 100:
    ax.yaxis.set_major_locator(ticker.MultipleLocator(base=1000)) # Línea principal cada 1000
    ax.yaxis.set_minor_locator(ticker.MultipleLocator(base=250))  # Línea fina cada 250

    # Mostrar la grid menor (fina)
    ax.grid(which='minor', axis='y', linestyle=':', linewidth=0.5, alpha=0.5, color='#dddddd')
    
    # Asegurar que la grid esté detrás de las barras
    ax.set_axisbelow(True)
    
    # Quitar la línea duplicada de plt.grid(True) que tenía al final
    # La configuración de ax.yaxis.grid() y ax.grid(which='minor'...) es más específica.
    
    plt.tight_layout() # Ajustar para que todo quepa bien
    plt.show()
    
else:
    print("DataFrame vacío o la columna 'churn' no existe.")

# %% [markdown]
# ### 2.2.2. Distribución de Evasión (Churn) por Variables Categóricas
#
# Exploraremos cómo se distribuye la evasión (`churn`) según diferentes características categóricas de los clientes. Esto nos ayudará a identificar si ciertos grupos de clientes tienen una mayor o menor propensión a la evasión.
#
# **A. Visualización de Conteos Absolutos de Churn por Categoría**

# %%
# CELDA: VISUALIZACIÓN DE CHURN POR VARIABLES CATEGÓRICAS (COUNTPLOTS MEJORADOS)

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd # Asegúrate que pd esté definido (DataFrame)
import numpy as np  # Asegúrate que np esté definido (para isinstance con np.integer)
from IPython.display import display

col_churn = 'churn' # Tu columna de evasión (0 o 1)

if not df.empty and col_churn in df.columns:
    print("--- ANÁLISIS DE EVASIÓN POR VARIABLES CATEGÓRICAS (CONTEOS) ---")
    
    categorical_multivalue_cols = df.select_dtypes(include=['object', 'category', 'string']).columns.tolist()
    if 'customerid' in categorical_multivalue_cols:
        categorical_multivalue_cols.remove('customerid')

    binary_cols_as_cat_for_plot = [
        'gender', 'seniorcitizen', 'partner', 'dependents', 
        'phoneservice', 'multiplelines', 'onlinesecurity', 
        'onlinebackup', 'deviceprotection', 'techsupport', 
        'streamingtv', 'streamingmovies', 'paperlessbilling'
    ]
    binary_cols_as_cat_for_plot = [col for col in binary_cols_as_cat_for_plot if col in df.columns]
    
    features_to_analyze = sorted(list(set(categorical_multivalue_cols + binary_cols_as_cat_for_plot)))

    churn_legend_map = {0: 'Permanecen', 1: 'Evaden'} # Para la leyenda

    for feature in features_to_analyze:
        if feature in df.columns and feature != col_churn:
            
            # --- Preparar datos para el plot ---
            data_plot_cat = df.copy()
            order_for_plot = None
            feature_label = feature.capitalize().replace("_", " ") # Para títulos y etiquetas de eje

            # Mapear valores numéricos binarios a etiquetas más descriptivas para el eje del gráfico
            if data_plot_cat[feature].dtype in ['int64', 'Int64'] and df[feature].nunique() == 2:
                unique_vals_feat = sorted(df[feature].dropna().unique().tolist())
                if len(unique_vals_feat) == 2 and all(isinstance(x, (int, np.integer)) for x in unique_vals_feat):
                    map_dict_feat = {unique_vals_feat[0]: f'No ({unique_vals_feat[0]})', 
                                     unique_vals_feat[1]: f'Sí ({unique_vals_feat[1]})'}
                    if feature == 'gender': map_dict_feat = {0: 'Female', 1: 'Male'} # Ejemplo específico
                    elif feature == 'seniorcitizen': map_dict_feat = {0: 'No Senior', 1: 'Senior'}
                    
                    data_plot_cat[feature] = data_plot_cat[feature].map(map_dict_feat)
                    order_for_plot = [map_dict_feat[val] for val in unique_vals_feat if val in map_dict_feat]
            
            # Si no se definió un orden específico, ordenar por frecuencia
            if order_for_plot is None:
                order_for_plot = data_plot_cat[feature].value_counts().index

            # --- Crear el Countplot ---
            plt.figure(figsize=(10, max(5, len(order_for_plot) * 0.6) )) # Ajustar altura dinámicamente
            
            ax = sns.countplot(
                data=data_plot_cat, 
                y=feature, 
                hue=df[col_churn].map(churn_legend_map), # Usar churn original mapeado para hue
                palette={'Permanecen': '#3498db', 'Evaden': '#e74c3c'}, # Paleta por nombre de categoría
                order=order_for_plot
            )
            
            plt.title(f'Distribución de Churn por {feature_label}', fontsize=16, fontweight='bold', pad=20)
            plt.xlabel('Número de Clientes', fontsize=13, fontweight='bold', labelpad=10)
            plt.ylabel(feature_label, fontsize=13, fontweight='bold', labelpad=10)
            
            ax.tick_params(axis='both', labelsize=11)
            sns.despine() # Quita spines superior y derecho por defecto

            # Mejorar leyenda
            handles, labels = ax.get_legend_handles_labels()
            ax.legend(handles, labels, title='Estado de Churn', title_fontsize='12', 
                      loc='center left', bbox_to_anchor=(1, 0.5)) # Leyenda fuera del gráfico

            # Anotaciones (opcional para countplot con hue, puede ser denso)
            # Si decides anotarlo:
            # for p in ax.patches:
            #     width = p.get_width()
            #     if width > 0: # Solo anotar si hay valor
            #         ax.text(width + (ax.get_xlim()[1] * 0.01), # Un pequeño offset desde el final de la barra
            #                 p.get_y() + p.get_height() / 2.,
            #                 f'{int(width)}',
            #                 ha='left', va='center', fontsize=9)
            
            plt.tight_layout(rect=[0, 0, 0.85, 1]) # Ajustar para que quepa la leyenda
            plt.show()
            print("-" * 70)
else:
    print(f"DataFrame vacío o la columna '{col_churn}' no disponible.")
# Out:
# --- ANÁLISIS DE EVASIÓN POR VARIABLES CATEGÓRICAS (CONTEOS) ---
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------

# %% [markdown]
# **B. Análisis de Tasas de Evasión por Categoría**
# Para profundizar, calcularemos y visualizaremos la tasa de evasión específica para cada categoría de las variables.

# %%
# CELDA: TASAS DE EVASIÓN Y GRÁFICOS APILADOS POR VARIABLES CATEGÓRICAS

col_churn = 'churn'

if not df.empty and col_churn in df.columns:
    print("\n--- ANÁLISIS DE TASA DE EVASIÓN POR VARIABLES CATEGÓRICAS ---")

    # Reusar features_to_analyze de la celda anterior o redefinirla aquí
    # (Asegúrate de que 'features_to_analyze' esté definida y sea la misma lista)
    if 'features_to_analyze' not in locals(): # Si esta celda se ejecuta independientemente
        categorical_multivalue_cols = df.select_dtypes(include=['object', 'category', 'string']).columns.tolist()
        if 'customerid' in categorical_multivalue_cols: categorical_multivalue_cols.remove('customerid')
        binary_cols_as_cat_for_plot = [
            'gender', 'seniorcitizen', 'partner', 'dependents', 'phoneservice', 'multiplelines', 
            'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport', 
            'streamingtv', 'streamingmovies', 'paperlessbilling'
        ]
        binary_cols_as_cat_for_plot = [col for col in binary_cols_as_cat_for_plot if col in df.columns]
        features_to_analyze = sorted(list(set(categorical_multivalue_cols + binary_cols_as_cat_for_plot)))


    for feature in features_to_analyze:
        if feature in df.columns and feature != col_churn:
            feature_label = feature.capitalize().replace("_", " ")

            if df[feature].isnull().sum() == 0 and df[col_churn].isnull().sum() == 0:
                print(f"\n--- Análisis para: {feature_label} ---")
                
                # Tabla Cruzada (ya la tenías y es útil)
                crosstab_df = pd.crosstab(df[feature], df[col_churn])
                crosstab_df.rename(columns={0: 'Permanecen', 1: 'Evaden'}, inplace=True)
                print("Tabla Cruzada (Conteos):")
                display(crosstab_df)

                # Porcentajes (normalize='index')
                crosstab_norm = pd.crosstab(df[feature], df[col_churn], normalize='index') * 100
                crosstab_norm.rename(columns={0:'% Permanecen', 1:'% Evaden'}, inplace=True)
                print("\nPorcentaje de Evasión/Permanencia por categoría:")
                display(crosstab_norm.sort_values(by='% Evaden', ascending=False))
                
                # --- Gráfico de barras de la Tasa de Evasión ---
                plt.figure(figsize=(8, max(4, crosstab_norm.shape[0]*0.4))) # Ajustar altura
                # Mapear índices numéricos (0/1) a etiquetas para el eje Y del gráfico de tasas
                plot_data_rate = crosstab_norm['% Evaden'].sort_values(ascending=True)
                y_labels_rate = plot_data_rate.index
                if df[feature].dtype in ['int64', 'Int64'] and df[feature].nunique() == 2:
                     unique_vals_feat = sorted(df[feature].dropna().unique().tolist())
                     map_dict_feat_rate = {unique_vals_feat[0]: f'No ({unique_vals_feat[0]})', 
                                           unique_vals_feat[1]: f'Sí ({unique_vals_feat[1]})'}
                     if feature == 'gender': map_dict_feat_rate = {0: 'Female', 1: 'Male'}
                     elif feature == 'seniorcitizen': map_dict_feat_rate = {0: 'No Senior', 1: 'Senior'}
                     y_labels_rate = plot_data_rate.index.map(map_dict_feat_rate)


                ax_rate = plot_data_rate.plot(kind='barh', color='#e74c3c', width=0.7)
                plt.title(f'Tasa de Evasión (%) por {feature_label}', fontsize=15, fontweight='bold', pad=15)
                plt.xlabel('Tasa de Evasión (%)', fontsize=12, fontweight='bold')
                plt.ylabel(feature_label, fontsize=12, fontweight='bold')
                ax_rate.set_yticklabels(y_labels_rate) # Aplicar etiquetas mapeadas
                plt.xlim(0, max(plot_data_rate.max() * 1.2, 20) if not plot_data_rate.empty else 100) # Ajustar límite X

                for index, value in enumerate(plot_data_rate):
                    plt.text(value + 0.5 , index, f'{value:.1f}%', va='center', ha='left', fontsize=9)
                
                sns.despine()
                plt.tight_layout()
                plt.show()

                # --- OPCIONAL: Gráfico de Barras Apiladas al 100% ---
                print(f"\n(Opcional) Gráfico de Barras Apiladas al 100% para {feature_label}:")
                ax_stacked = crosstab_norm[['% Permanecen', '% Evaden']].sort_values(by='% Evaden').plot(
                    kind='barh', 
                    stacked=True, 
                    figsize=(10, max(4, crosstab_norm.shape[0]*0.4)), 
                    color={'% Permanecen': '#3498db', '% Evaden': '#e74c3c'},
                    width=0.8
                )
                plt.title(f'Proporción de Churn por {feature_label}', fontsize=15, fontweight='bold', pad=20)
                plt.xlabel('Porcentaje de Clientes (%)', fontsize=12, fontweight='bold')
                plt.ylabel(feature_label, fontsize=12, fontweight='bold')
                ax_stacked.set_yticklabels(y_labels_rate) # Aplicar etiquetas mapeadas si es necesario
                plt.legend(title='Estado de Churn', bbox_to_anchor=(1.02, 1), loc='upper left')
                plt.xlim(0, 100)
                
                # Anotaciones para barras apiladas (pueden ser un poco complejas de ajustar)
                for n, (idx, row) in enumerate(crosstab_norm[['% Permanecen', '% Evaden']].sort_values(by='% Evaden').iterrows()):
                    cumulative_width = 0
                    for i, (colname, value) in enumerate(row.items()):
                        if value > 5: # Solo anotar si el segmento es mayor al 5% para no saturar
                            bar_width = value
                            label = f'{value:.0f}%' # Porcentaje redondeado
                            x_pos = cumulative_width + bar_width / 2
                            ax_stacked.text(x_pos, n, label, ha='center', va='center', color='white', fontsize=8, fontweight='bold')
                        cumulative_width += value
                
                sns.despine()
                plt.tight_layout(rect=[0, 0, 0.85, 1])
                plt.show()
                print("-" * 70)

            else:
                print(f"Advertencia: La columna '{feature}' o '{col_churn}' contiene NaNs, omitiendo crosstab y gráficos de tasas.")
        else:
            print(f"Advertencia: La columna categórica '{feature}' no existe en el DataFrame.")
else:
    print(f"DataFrame vacío o la columna '{col_churn}' no disponible.")
# Out:
# --- ANÁLISIS DE TASA DE EVASIÓN POR VARIABLES CATEGÓRICAS ---
#
# --- Análisis para: Contract ---
# Tabla Cruzada (Conteos):
# churn           Permanecen  Evaden
# contract
# month-to-month        2220    1655
# one_year              1307     166
# two_year              1647      48
# Porcentaje de Evasión/Permanencia por categoría:
# churn           % Permanecen   % Evaden
# contract
# month-to-month     57.290323  42.709677
# one_year           88.730482  11.269518
# two_year           97.168142   2.831858
# (Opcional) Gráfico de Barras Apiladas al 100% para Contract:
# ----------------------------------------------------------------------
#
# --- Análisis para: Dependents ---
# Tabla Cruzada (Conteos):
# churn       Permanecen  Evaden
# dependents
# 0                 3390    1543
# 1                 1784     326
# Porcentaje de Evasión/Permanencia por categoría:
# churn       % Permanecen   % Evaden
# dependents
# 0              68.720860  31.279140
# 1              84.549763  15.450237
# (Opcional) Gráfico de Barras Apiladas al 100% para Dependents:
# ----------------------------------------------------------------------
#
# --- Análisis para: Deviceprotection ---
# Tabla Cruzada (Conteos):
# churn             Permanecen  Evaden
# deviceprotection
# 0                       3297    1324
# 1                       1877     545
# Porcentaje de Evasión/Permanencia por categoría:
# churn             % Permanecen   % Evaden
# deviceprotection
# 0                    71.348193  28.651807
# 1                    77.497936  22.502064
# (Opcional) Gráfico de Barras Apiladas al 100% para Deviceprotection:
# ----------------------------------------------------------------------
#
# --- Análisis para: Gender ---
# Tabla Cruzada (Conteos):
# churn   Permanecen  Evaden
# gender
# 0             2549     939
# 1             2625     930
# Porcentaje de Evasión/Permanencia por categoría:
# churn   % Permanecen   % Evaden
# gender
# 0          73.079128  26.920872
# 1          73.839662  26.160338
# (Opcional) Gráfico de Barras Apiladas al 100% para Gender:
# ----------------------------------------------------------------------
#
# --- Análisis para: Internetservice ---
# Tabla Cruzada (Conteos):
# churn            Permanecen  Evaden
# internetservice
# dsl                    1962     459
# fiber_optic            1799    1297
# no                     1413     113
# Porcentaje de Evasión/Permanencia por categoría:
# churn            % Permanecen   % Evaden
# internetservice
# fiber_optic         58.107235  41.892765
# dsl                 81.040892  18.959108
# no                  92.595020   7.404980
# (Opcional) Gráfico de Barras Apiladas al 100% para Internetservice:
# ----------------------------------------------------------------------
#
# --- Análisis para: Multiplelines ---
# Tabla Cruzada (Conteos):
# churn          Permanecen  Evaden
# multiplelines
# 0                    3053    1019
# 1                    2121     850
# Porcentaje de Evasión/Permanencia por categoría:
# churn          % Permanecen   % Evaden
# multiplelines
# 1                 71.390104  28.609896
# 0                 74.975442  25.024558
# (Opcional) Gráfico de Barras Apiladas al 100% para Multiplelines:
# ----------------------------------------------------------------------
#
# --- Análisis para: Onlinebackup ---
# Tabla Cruzada (Conteos):
# churn         Permanecen  Evaden
# onlinebackup
# 0                   3268    1346
# 1                   1906     523
# Porcentaje de Evasión/Permanencia por categoría:
# churn         % Permanecen   % Evaden
# onlinebackup
# 0                70.827915  29.172085
# 1                78.468506  21.531494
# (Opcional) Gráfico de Barras Apiladas al 100% para Onlinebackup:
# ----------------------------------------------------------------------
#
# --- Análisis para: Onlinesecurity ---
# Tabla Cruzada (Conteos):
# churn           Permanecen  Evaden
# onlinesecurity
# 0                     3450    1574
# 1                     1724     295
# Porcentaje de Evasión/Permanencia por categoría:
# churn           % Permanecen   % Evaden
# onlinesecurity
# 0                  68.670382  31.329618
# 1                  85.388806  14.611194
# (Opcional) Gráfico de Barras Apiladas al 100% para Onlinesecurity:
# ----------------------------------------------------------------------
#
# --- Análisis para: Paperlessbilling ---
# Tabla Cruzada (Conteos):
# churn             Permanecen  Evaden
# paperlessbilling
# 0                       2403     469
# 1                       2771    1400
# Porcentaje de Evasión/Permanencia por categoría:
# churn             % Permanecen   % Evaden
# paperlessbilling
# 1                    66.434908  33.565092
# 0                    83.669916  16.330084
# (Opcional) Gráfico de Barras Apiladas al 100% para Paperlessbilling:
# ----------------------------------------------------------------------
#
# --- Análisis para: Partner ---
# Tabla Cruzada (Conteos):
# churn    Permanecen  Evaden
# partner
# 0              2441    1200
# 1              2733     669
# Porcentaje de Evasión/Permanencia por categoría:
# churn    % Permanecen   % Evaden
# partner
# 0           67.042021  32.957979
# 1           80.335097  19.664903
# (Opcional) Gráfico de Barras Apiladas al 100% para Partner:
# ----------------------------------------------------------------------
#
# --- Análisis para: Paymentmethod ---
# Tabla Cruzada (Conteos):
# churn                    Permanecen  Evaden
# paymentmethod
# bank_transfer_automatic        1286     258
# credit_card_automatic          1290     232
# electronic_check               1294    1071
# mailed_check                   1304     308
# Porcentaje de Evasión/Permanencia por categoría:
# churn                    % Permanecen   % Evaden
# paymentmethod
# electronic_check            54.714588  45.285412
# mailed_check                80.893300  19.106700
# bank_transfer_automatic     83.290155  16.709845
# credit_card_automatic       84.756899  15.243101
# (Opcional) Gráfico de Barras Apiladas al 100% para Paymentmethod:
# ----------------------------------------------------------------------
#
# --- Análisis para: Phoneservice ---
# Tabla Cruzada (Conteos):
# churn         Permanecen  Evaden
# phoneservice
# 0                    512     170
# 1                   4662    1699
# Porcentaje de Evasión/Permanencia por categoría:
# churn         % Permanecen   % Evaden
# phoneservice
# 1                73.290363  26.709637
# 0                75.073314  24.926686
# (Opcional) Gráfico de Barras Apiladas al 100% para Phoneservice:
# ----------------------------------------------------------------------
#
# --- Análisis para: Seniorcitizen ---
# Tabla Cruzada (Conteos):
# churn          Permanecen  Evaden
# seniorcitizen
# 0                    4508    1393
# 1                     666     476
# Porcentaje de Evasión/Permanencia por categoría:
# churn          % Permanecen   % Evaden
# seniorcitizen
# 1                 58.318739  41.681261
# 0                 76.393832  23.606168
# (Opcional) Gráfico de Barras Apiladas al 100% para Seniorcitizen:
# ----------------------------------------------------------------------
#
# --- Análisis para: Streamingmovies ---
# Tabla Cruzada (Conteos):
# churn            Permanecen  Evaden
# streamingmovies
# 0                      3260    1051
# 1                      1914     818
# Porcentaje de Evasión/Permanencia por categoría:
# churn            % Permanecen   % Evaden
# streamingmovies
# 1                   70.058565  29.941435
# 0                   75.620506  24.379494
# (Opcional) Gráfico de Barras Apiladas al 100% para Streamingmovies:
# ----------------------------------------------------------------------
#
# --- Análisis para: Streamingtv ---
# Tabla Cruzada (Conteos):
# churn        Permanecen  Evaden
# streamingtv
# 0                  3281    1055
# 1                  1893     814
# Porcentaje de Evasión/Permanencia por categoría:
# churn        % Permanecen   % Evaden
# streamingtv
# 1               69.929812  30.070188
# 0               75.668819  24.331181
# (Opcional) Gráfico de Barras Apiladas al 100% para Streamingtv:
# ----------------------------------------------------------------------
#
# --- Análisis para: Techsupport ---
# Tabla Cruzada (Conteos):
# churn        Permanecen  Evaden
# techsupport
# 0                  3440    1559
# 1                  1734     310
# Porcentaje de Evasión/Permanencia por categoría:
# churn        % Permanecen   % Evaden
# techsupport
# 0               68.813763  31.186237
# 1               84.833659  15.166341
# (Opcional) Gráfico de Barras Apiladas al 100% para Techsupport:
# ----------------------------------------------------------------------

# %% [markdown]
# #📄Informe final
